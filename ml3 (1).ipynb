# %%
import pandas as pd
df = pd.read_csv('/content/gender_submission (1).csv')
print(df.head())
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# dtype: int64

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
import numpy as np

# %%
x=np.array(x).reshape(-1,1)
y=np.array(y).reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(
    x,y,test_size=0.2,random_state=42
)
print("Training samples:",x_train.shape)
print("Testing samples:",x_test.shape)
# Out:
# Training samples: (334, 1)
# Testing samples: (84, 1)

# %%
from sklearn.svm import SVC

# %%
svm_linear = SVC(kernel = 'rbf',class_weight='balanced',C=0.1)
svm_linear.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=0.1, class_weight='balanced')

# %%
y_pred=svm_linear.predict(x_test)

# %%
from sklearn.metrics import f1_score
f1_score(y_test,y_pred)
# Out:
# 0.5636363636363636

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
accuracy_score(y_test,y_pred)
print("Acuracy score:",accuracy_score(y_test,y_pred))
print("Confusion matrix:\n",confusion_matrix(y_test,y_pred))
print("Classification report:\n",classification_report(y_test,y_pred))
# Out:
# Acuracy score: 0.42857142857142855
# Confusion matrix:
#  [[ 5 45]
#  [ 3 31]]
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.10      0.17        50
#            1       0.41      0.91      0.56        34
#
#     accuracy                           0.43        84
#    macro avg       0.52      0.51      0.37        84
# weighted avg       0.54      0.43      0.33        84

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True,cmap='Blues',fmt='d')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.hist(df['PassengerId'], bins=30, edgecolor='black')
plt.title('Distribution of Passenger IDs')
plt.xlabel('Passenger ID')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.countplot(x=df['Survived'])
plt.title('Distribution of Survived Status')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Count')
plt.show()

# %%
print("Traning samples:",x_train.shape)
print("Testing samples:",x_test.shape)
# Out:
# Traning samples: (334, 1)
# Testing samples: (84, 1)
